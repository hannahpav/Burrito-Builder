# %%
import pandas as pd
import sqlite3
import openpyxl
import csv
import re

# %%
def excel_to_sqlite(excel_file, db_file):
    # Connect to SQLite database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()
    
    cursor.execute("DROP TABLE IF EXISTS emissions")

    # Load the Excel workbook
    wb = openpyxl.load_workbook(excel_file, read_only=True)
    sheet = wb.active

    # Get column names from the first row
    columns = next(sheet.iter_rows(values_only=True))

    # Create table with dynamic column names
    create_table_sql = f'''CREATE TABLE IF NOT EXISTS emissions (
        {', '.join([f'"{col}" TEXT' for col in columns])}
    )'''
    cursor.execute(create_table_sql)

    # Prepare INSERT statement
    insert_sql = f'''INSERT INTO emissions VALUES (
        {', '.join(['?' for _ in columns])}
    )'''

    # Insert data
    for row in sheet.iter_rows(min_row=2, values_only=True):
        cursor.execute(insert_sql, row)

    conn.commit()
    conn.close()


def execute_query(db_file, query, fetch=True):
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()
    cursor.execute(query)
    if fetch:
        results = cursor.fetchall()
    else:
        results = None
        conn.commit()
    conn.close()
    return results

def get_column_names(db_file):
    query = "PRAGMA table_info(emissions)"
    columns = execute_query(db_file, query)
    return [col[1] for col in columns]

def get_unique_values(db_file, column):
    query = f'SELECT DISTINCT "{column}" FROM emissions'
    return execute_query(db_file, query)

def count_unique_values(db_file, column):
    query = f'SELECT COUNT(DISTINCT "{column}") FROM emissions'
    return execute_query(db_file, query)[0][0]

# %%
# excel_file = 'Emissions_Totals_E_All_Data.xlsx'
db_file = 'emissions.db'

# excel_to_sqlite(excel_file, db_file)

# # Get column names
# columns = get_column_names(db_file)
# print("Columns in the table:", columns)

# # Example usage for each column
# for column in columns:co
#     print(f"\nColumn: {column}")
#     unique_values = get_unique_values(db_file, column)
#     print(f"Sample unique values (up to 5): {unique_values[:5]}")
#     unique_count = count_unique_values(db_file, column)
#     print(f"Number of unique values: {unique_count}")

# # Example of getting unique combinations of two columns
# if len(columns) >= 2:
#     query = f'SELECT DISTINCT "{columns[0]}", "{columns[1]}" FROM emissions LIMIT 5'
#     unique_combinations = execute_query(db_file, query)
#     print(f"\nSample unique combinations of {columns[0]} and {columns[1]}:")
#     for combo in unique_combinations:
#         print(combo)

# %% [markdown]
# def filter_columns(db_file):
#     # Get current column names
#     columns = execute_query(db_file, "PRAGMA table_info(emissions)")
#     columns = [col[1] for col in columns]
#
#     # Filter columns
#     keep_columns = [col for col in columns if not col.startswith('Y') or col == 'Y2021']
#
#     # Create new table with filtered columns
#     create_table_sql = f'''CREATE TABLE emissions_filtered (
#         {', '.join([f'"{col}" TEXT' for col in keep_columns])}
#     )'''
#     execute_query(db_file, create_table_sql, fetch=False)
#
#     # Copy data to new table
#     copy_data_sql = f'''INSERT INTO emissions_filtered
#         SELECT {', '.join([f'"{col}"' for col in keep_columns])}
#         FROM emissions'''
#     execute_query(db_file, copy_data_sql, fetch=False)
#
#     # Drop old table and rename new table
#     execute_query(db_file, "DROP TABLE emissions", fetch=False)
#     execute_query(db_file, "ALTER TABLE emissions_filtered RENAME TO emissions", fetch=False)
#
# # Use the function to filter columns
# filter_columns(db_file)

# %%
def inspect_table(db_file, table_name, limit=5):
    # Get column names
    columns = execute_query(db_file, f"PRAGMA table_info({table_name})")
    column_names = [col[1] for col in columns]
    print(f"Columns in {table_name}:")
    print(", ".join(column_names))
    print("\nSample data:")

    # Get sample data
    sample_data = execute_query(db_file, f"SELECT * FROM {table_name} LIMIT {limit}")
    
    # Print sample data
    for row in sample_data:
        print(row)

    # Get row count
    row_count = execute_query(db_file, f"SELECT COUNT(*) FROM {table_name}")[0][0]
    print(f"\nTotal number of rows: {row_count}")

# Use the function to inspect the table
inspect_table(db_file, 'emissions')
# Out:
# Columns in emissions:
#
#
# Sample data:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 21
#      18     print(f"\nTotal number of rows: {row_count}")
#      20 # Use the function to inspect the table
# ---> 21 inspect_table(db_file, 'emissions')
#
# Cell In[4], line 10, in inspect_table(db_file, table_name, limit)
#       7 print("\nSample data:")
#       9 # Get sample data
# ---> 10 sample_data = execute_query(db_file, f"SELECT * FROM {table_name} LIMIT {limit}")
#      12 # Print sample data
#      13 for row in sample_data:
#
# Cell In[2], line 37, in execute_query(db_file, query, fetch)
#      35 conn = sqlite3.connect(db_file)
#      36 cursor = conn.cursor()
# ---> 37 cursor.execute(query)
#      38 if fetch:
#      39     results = cursor.fetchall()
#
# OperationalError: no such table: emissions

# %%
execute_query(db_file, f"SELECT * FROM countryCode LIMIT 10")

# %%
execute_query(db_file, f"SELECT DISTINCT(Unit) FROM emissions")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 execute_query(db_file, f"SELECT DISTINCT(Unit) FROM emissions")
#
# Cell In[2], line 37, in execute_query(db_file, query, fetch)
#      35 conn = sqlite3.connect(db_file)
#      36 cursor = conn.cursor()
# ---> 37 cursor.execute(query)
#      38 if fetch:
#      39     results = cursor.fetchall()
#
# OperationalError: no such table: emissions

# %% [markdown]
# ### Trade Emissions Data

# %%
import sqlite3
import pandas as pd
import csv

def csv_to_sqlite(csv_file, db_file, table_name='tradeEmissions'):
    # Read CSV file using pandas, with missing values handled
    df = pd.read_csv(csv_file, encoding='utf-8', na_values=[''], keep_default_na=True)
    
    # Replace NaN with None for SQLite compatibility
    df = df.where(pd.notnull(df), None)

    # Connect to SQLite database
    conn = sqlite3.connect(db_file)
    
    # Write the data to a sqlite table
    df.to_sql(table_name, conn, if_exists='replace', index=False)
    
    conn.close()
    print(f"Data imported successfully into table '{table_name}'")

    # Print some information about the imported data
    print(f"Number of rows imported: {len(df)}")
    print(f"Columns: {', '.join(df.columns)}")

    # Print first few rows
    print("\nFirst few rows of data:")
    print(df.head().to_string())

# Usage
csv_file = 'TradeData_10_17_2024_13_19_5_cleaned_dropped_zero_cost_countries.csv'
csv_to_sqlite(csv_file, db_file)
# Out:
# Data imported successfully into table 'tradeEmissions'
# Number of rows imported: 19562
# Columns: refYear, countryCode, countryISO, partnerCountryCode, partnerCountryISO, HSCode, cmdCode, motCode, Units, netWeight, grossWeight, cifvalue, costPerKg
#
# First few rows of data:
#    refYear countryCode countryISO partnerCountryCode partnerCountryISO  HSCode                                                   cmdCode    motCode Units  netWeight   grossWeight      cifvalue  costPerKg
# 0     2023         ARG  Argentina                W00             World   20130  Meat; of bovine animals, boneless cuts, fresh or chilled  TOTAL MOT    kg   69700.15  7.642760e+05  7.087275e+05  10.168235
# 1     2023         ARG  Argentina                ARG         Argentina   20130  Meat; of bovine animals, boneless cuts, fresh or chilled  TOTAL MOT    kg   69700.15  7.642760e+05  7.087275e+05  10.168235
# 2     2023         AUS  Australia                W00             World   20130  Meat; of bovine animals, boneless cuts, fresh or chilled  TOTAL MOT    kg  472097.08  1.176214e+07  1.069612e+07  22.656605
# 3     2023         AUS  Australia                AUS         Australia   20130  Meat; of bovine animals, boneless cuts, fresh or chilled  TOTAL MOT    kg   52778.78  8.326905e+05  8.231955e+05  15.597091
# 4     2023         AUS  Australia                JPN             Japan   20130  Meat; of bovine animals, boneless cuts, fresh or chilled  TOTAL MOT    kg  111349.30  7.954896e+06  7.044398e+06  63.263966

# %%
execute_query(db_file, f"""SELECT "motCode" FROM tradeEmissions""")
# Out:
# [('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Air',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Sea',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Road',),
#  ('Postal consignments, mail or courier shipment',),
#  ('Postal consignments, mail or courier shipment',),
#  ('Postal consignments, mail or courier shipment',),
#  ('Postal consignments, mail or courier shipment',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ('TOTAL MOT',),
#  ...]

# %% [markdown]
# ## Geo Location Table

# %%
def csv_to_sqlite(csv_file, db_file, table_name='countryDistance'):
    # Read CSV file using pandas, with missing values handled
    df = pd.read_csv(csv_file, encoding='utf-8', na_values=[''], keep_default_na=True)
    
    # Replace NaN with None for SQLite compatibility
    df = df.where(pd.notnull(df), None)

    # Connect to SQLite database
    conn = sqlite3.connect(db_file)
    
    # Write the data to a sqlite table
    df.to_sql(table_name, conn, if_exists='replace', index=False)
    
    conn.close()
    print(f"Data imported successfully into table '{table_name}'")

    # Print some information about the imported data
    print(f"Number of rows imported: {len(df)}")
    print(f"Columns: {', '.join(df.columns)}")

    # Print first few rows
    print("\nFirst few rows of data:")
    print(df.head().to_string())

# Usage
csv_file = 'country-distances.csv'
csv_to_sqlite(csv_file, db_file)
# Out:
# Data imported successfully into table 'countryDistance'
# Number of rows imported: 235
# Columns:  , ABW, AFG, AGO, AIA, ALB, AND, ARE, ARG, ARM, ASM, ATA, ATF, ATG, AUS, AUT, AZE, BDI, BEL, BEN, BES, BFA, BGD, BGR, BHR, BHS, BIH, BLM, BLR, BLZ, BMU, BOL, BRA, BRB, BTN, BWA, CAF, CAN, CCK, CHE, CHL, CHN, CIV, CMR, COD, COG, COK, COL, COM, CPV, CRI, CUB, CUW, CXR, CYM, CYP, CZE, DEU, DJI, DMA, DNK, DOM, DZA, ECU, EGY, ERI, ESH, ESP, EST, ETH, FIN, FJI, FRA, FRO, FSM, GAB, GBR, GEO, GGY, GHA, GIB, GIN, GLP, GMB, GNB, GNQ, GRC, GRD, GRL, GTM, GUF, GUM, GUY, HKG, HND, HRV, HTI, HUN, IDN, IMN, IND, IOT, IRL, IRN, IRQ, ISL, ISR, ITA, JAM, JEY, JOR, JPN, KAZ, KEN, KGZ, KHM, KIR, KNA, KWT, LBN, LBR, LBY, LCA, LIE, LKA, LSO, LTU, LUX, LVA, MAC, MAR, MCO, MDA, MDG, MDV, MEX, MHL, MKD, MLI, MLT, MMR, MNE, MNG, MNP, MOZ, MRT, MSR, MTQ, MUS, MWI, MYS, MYT, NAM, NCL, NER, NFK, NGA, NIC, NIU, NLD, NOR, NPL, NRU, NZL, OMN, PAK, PAN, PCN, PER, PHL, PLW, PNG, POL, PRI, PRT, PRY, PSE, PYF, QAT, REU, ROU, RUS, RWA, SAU, SDN, SEN, SGP, SGS, SHN, SJM, SLB, SLE, SLV, SMR, SOM, SPM, SRB, SSD, STP, SUR, SVK, SVN, SWE, SWZ, SYC, SYR, TCA, TCD, TGO, THA, TJK, TKL, TKM, TLS, TON, TTO, TUN, TUR, TUV, TWN, TZA, UGA, UKR, URY, USA, UZB, VCT, VEN, VNM, VUT, WLF, WSM, YEM, ZAF, ZMB, ZWE
#
# First few rows of data:
#                  ABW           AFG          AGO           AIA          ALB          AND           ARE           ARG           ARM           ASM           ATA           ATF           ATG           AUS          AUT           AZE           BDI          BEL          BEN           BES          BFA           BGD          BGR           BHR           BHS          BIH           BLM          BLR           BLZ           BMU           BOL           BRA           BRB           BTN           BWA          CAF           CAN           CCK          CHE           CHL           CHN          CIV          CMR           COD          COG           COK           COL           COM          CPV           CRI           CUB           CUW           CXR           CYM           CYP          CZE          DEU           DJI           DMA          DNK           DOM          DZA           ECU           EGY           ERI          ESH          ESP          EST           ETH          FIN           FJI          FRA          FRO           FSM          GAB          GBR           GEO          GGY          GHA                 GIB          GIN           GLP          GMB          GNB          GNQ          GRC           GRD          GRL           GTM           GUF           GUM           GUY           HKG           HND          HRV           HTI          HUN           IDN          IMN           IND           IOT          IRL           IRN           IRQ          ISL           ISR          ITA           JAM          JEY           JOR           JPN           KAZ           KEN           KGZ           KHM           KIR           KNA           KWT           LBN          LBR          LBY           LCA          LIE           LKA           LSO          LTU          LUX          LVA           MAC          MAR          MCO          MDA           MDG           MDV           MEX           MHL          MKD          MLI          MLT           MMR          MNE           MNG           MNP           MOZ          MRT           MSR           MTQ           MUS           MWI           MYS           MYT           NAM           NCL          NER           NFK          NGA           NIC           NIU          NLD          NOR           NPL           NRU                 NZL           OMN           PAK           PAN           PCN           PER           PHL           PLW           PNG          POL           PRI          PRT                 PRY           PSE           PYF           QAT           REU          ROU          RUS           RWA           SAU           SDN          SEN           SGP           SGS          SHN          SJM           SLB          SLE           SLV          SMR           SOM          SPM          SRB           SSD          STP           SUR          SVK          SVN          SWE           SWZ           SYC           SYR           TCA          TCD          TGO           THA           TJK           TKL           TKM           TLS           TON           TTO          TUN          TUR           TUV                 TWN           TZA           UGA          UKR           URY           USA           UZB           VCT           VEN           VNM           VUT           WLF           WSM           YEM           ZAF           ZMB           ZWE
   1773.180492   9509.888887   4621.334341   5021.943185   4452.477561   8764.585062  14564.059387   8148.442225   2892.001336   1607.923735  4925.432996  1107.049007   8235.994405  1046.787415   7019.455616   7861.060893  1539.366160  1408.062365  1764.028204   8711.543766  2561.385300  1052.282582   958.388365   7256.862647   6730.780713  10811.230473  13914.060991   153.481284  4172.055357   761.969160   7665.966908   131.996577   6572.518780  11646.874494   7565.602177  4267.258503   8140.685222   8198.542149   7839.651663   6288.359789   8930.954065   6535.461022   7078.338474  16256.362273  3528.776235  16841.046996  4192.885056  10431.127589  17370.475463  1668.163425  2160.099949   6056.107557  14412.945061   17808.06762291933   4093.566544   4703.661783  10127.004096  16711.793825  11454.542589   9856.254441  11473.877761  13783.587227  1215.338995   8345.412146  2476.872642  10855.246379749184   1735.077787  17183.821937   3418.468875   7807.704005   618.441366  2061.008373   4903.439657   3096.671890   3108.343040  4645.656943   9417.929012  11873.611526  6863.964862  4113.776702  14750.104216  4880.500017  10540.228232   669.082847   5048.519150  5878.374228   389.786211   4207.149911  4727.497431   8328.915538   787.671198   677.142363  2006.490427   7603.261181   6243.202268   1607.612428   8543.933390  3271.383999  4313.787722   8241.109128   4140.800614  16175.869989   3304.251469  11950.725486  17362.959257   8514.195116   972.935634   766.670762  15845.803428   9120.351630721923   5689.225329   4720.551803  1308.556375  11460.923888   7454.756434   4079.426472   8313.202282   8974.865549   8960.200423  16037.392002  16534.505765  16759.477394   3714.765270   8333.606713   6341.330364   6650.773482

# %%
execute_query(db_file, f"""
    select ABW from countryDistance
    Limit 10""")
# Out:
# [(0.0,),
#  (13252.562556919602,),
#  (9500.724683275826,),
#  (973.5351203846636,),
#  (9085.425408426994,),
#  (7565.414509724316,),
#  (12767.098434098489,),
#  (5360.114080711346,),
#  (11105.217199030116,),
#  (11491.1503575087,)]

# %% [markdown]
# ## attach country codes to distance

# %%
def transform_distance_matrix(db_file):
    # First drop the normalized table if it exists
    drop_table_query = """
    DROP TABLE IF EXISTS normalized_distances;
    """
    execute_query(db_file, drop_table_query, fetch=False)
    
    # Create the normalized table with the correct structure
    create_table_query = """
    CREATE TABLE normalized_distances (
        origin_country TEXT,
        destination_country TEXT,
        distance FLOAT
    );
    """
    execute_query(db_file, create_table_query, fetch=False)
    
    # Get column names using pragma
    columns_query = """
    SELECT name FROM pragma_table_info('countryDistance');
    """
    columns = [row[0] for row in execute_query(db_file, columns_query, fetch=True)]
    columns = columns[1:]  # Remove the first column name since it's the row identifier
    
    # For each country pair, insert into normalized_distances
    for origin_country in columns:
        insert_query = f"""
        INSERT INTO normalized_distances (origin_country, destination_country, distance)
        SELECT 
            '{origin_country}' as origin_country,
            [0] as destination_country,
            [{origin_country}] as distance
        FROM countryDistance;
        """
        try:
            execute_query(db_file, insert_query, fetch=False)
        except Exception as e:
            print(f"Error inserting data for {origin_country}: {str(e)}")
            continue
    
    # Create index for better performance
    index_query = """
    CREATE INDEX idx_orig_dest ON normalized_distances(origin_country, destination_country);
    """
    execute_query(db_file, index_query, fetch=False)

def get_trade_emissions_with_distances(db_file):
    query = """
    SELECT 
        t.*,
        nd.distance
    FROM tradeEmissions t
    LEFT JOIN normalized_distances nd
        ON t.countryCode = nd.origin_country 
        AND t.partnerCountryCode = nd.destination_country;
    """
    return execute_query(db_file, query)

# Usage:
db_file = "your_database.db"  # Replace with your database file path

# First transform the matrix
transform_distance_matrix(db_file)

# Then get the results
results = get_trade_emissions_with_distances(db_file)
# Out:
# Error inserting data for ABW: no such column: 0
# Error inserting data for AFG: no such column: 0
# Error inserting data for AGO: no such column: 0
# Error inserting data for AIA: no such column: 0
# Error inserting data for ALB: no such column: 0
# Error inserting data for AND: no such column: 0
# Error inserting data for ARE: no such column: 0
# Error inserting data for ARG: no such column: 0
# Error inserting data for ARM: no such column: 0
# Error inserting data for ASM: no such column: 0
# Error inserting data for ATA: no such column: 0
# Error inserting data for ATF: no such column: 0
# Error inserting data for ATG: no such column: 0
# Error inserting data for AUS: no such column: 0
# Error inserting data for AUT: no such column: 0
# Error inserting data for AZE: no such column: 0
# Error inserting data for BDI: no such column: 0
# Error inserting data for BEL: no such column: 0
# Error inserting data for BEN: no such column: 0
# Error inserting data for BES: no such column: 0
# Error inserting data for BFA: no such column: 0
# Error inserting data for BGD: no such column: 0
# Error inserting data for BGR: no such column: 0
# Error inserting data for BHR: no such column: 0
# Error inserting data for BHS: no such column: 0
# Error inserting data for BIH: no such column: 0
# Error inserting data for BLM: no such column: 0
# Error inserting data for BLR: no such column: 0
# Error inserting data for BLZ: no such column: 0
# Error inserting data for BMU: no such column: 0
# Error inserting data for BOL: no such column: 0
# Error inserting data for BRA: no such column: 0
# Error inserting data for BRB: no such column: 0
# Error inserting data for BTN: no such column: 0
# Error inserting data for BWA: no such column: 0
# Error inserting data for CAF: no such column: 0
# Error inserting data for CAN: no such column: 0
# Error inserting data for CCK: no such column: 0
# Error inserting data for CHE: no such column: 0
# Error inserting data for CHL: no such column: 0
# Error inserting data for CHN: no such column: 0
# Error inserting data for CIV: no such column: 0
# Error inserting data for CMR: no such column: 0
# Error inserting data for COD: no such column: 0
# Error inserting data for COG: no such column: 0
# Error inserting data for COK: no such column: 0
# Error inserting data for COL: no such column: 0
# Error inserting data for COM: no such column: 0
# Error inserting data for CPV: no such column: 0
# Error inserting data for CRI: no such column: 0
# Error inserting data for CUB: no such column: 0
# Error inserting data for CUW: no such column: 0
# Error inserting data for CXR: no such column: 0
# Error inserting data for CYM: no such column: 0
# Error inserting data for CYP: no such column: 0
# Error inserting data for CZE: no such column: 0
# Error inserting data for DEU: no such column: 0
# Error inserting data for DJI: no such column: 0
# Error inserting data for DMA: no such column: 0
# Error inserting data for DNK: no such column: 0
# Error inserting data for DOM: no such column: 0
# Error inserting data for DZA: no such column: 0
# Error inserting data for ECU: no such column: 0
# Error inserting data for EGY: no such column: 0
# Error inserting data for ERI: no such column: 0
# Error inserting data for ESH: no such column: 0
# Error inserting data for ESP: no such column: 0
# Error inserting data for EST: no such column: 0
# Error inserting data for ETH: no such column: 0
# Error inserting data for FIN: no such column: 0
# Error inserting data for FJI: no such column: 0
# Error inserting data for FRA: no such column: 0
# Error inserting data for FRO: no such column: 0
# Error inserting data for FSM: no such column: 0
# Error inserting data for GAB: no such column: 0
# Error inserting data for GBR: no such column: 0
# Error inserting data for GEO: no such column: 0
# Error inserting data for GGY: no such column: 0
# Error inserting data for GHA: no such column: 0
# Error inserting data for GIB: no such column: 0
# Error inserting data for GIN: no such column: 0
# Error inserting data for GLP: no such column: 0
# Error inserting data for GMB: no such column: 0
# Error inserting data for GNB: no such column: 0
# Error inserting data for GNQ: no such column: 0
# Error inserting data for GRC: no such column: 0
# Error inserting data for GRD: no such column: 0
# Error inserting data for GRL: no such column: 0
# Error inserting data for GTM: no such column: 0
# Error inserting data for GUF: no such column: 0
# Error inserting data for GUM: no such column: 0
# Error inserting data for GUY: no such column: 0
# Error inserting data for HKG: no such column: 0
# Error inserting data for HND: no such column: 0
# Error inserting data for HRV: no such column: 0
# Error inserting data for HTI: no such column: 0
# Error inserting data for HUN: no such column: 0
# Error inserting data for IDN: no such column: 0
# Error inserting data for IMN: no such column: 0
# Error inserting data for IND: no such column: 0
# Error inserting data for IOT: no such column: 0
# Error inserting data for IRL: no such column: 0
# Error inserting data for IRN: no such column: 0
# Error inserting data for IRQ: no such column: 0
# Error inserting data for ISL: no such column: 0
# Error inserting data for ISR: no such column: 0
# Error inserting data for ITA: no such column: 0
# Error inserting data for JAM: no such column: 0
# Error inserting data for JEY: no such column: 0
# Error inserting data for JOR: no such column: 0
# Error inserting data for JPN: no such column: 0
# Error inserting data for KAZ: no such column: 0
# Error inserting data for KEN: no such column: 0
# Error inserting data for KGZ: no such column: 0
# Error inserting data for KHM: no such column: 0
# Error inserting data for KIR: no such column: 0
# Error inserting data for KNA: no such column: 0
# Error inserting data for KWT: no such column: 0
# Error inserting data for LBN: no such column: 0
# Error inserting data for LBR: no such column: 0
# Error inserting data for LBY: no such column: 0
# Error inserting data for LCA: no such column: 0
# Error inserting data for LIE: no such column: 0
# Error inserting data for LKA: no such column: 0
# Error inserting data for LSO: no such column: 0
# Error inserting data for LTU: no such column: 0
# Error inserting data for LUX: no such column: 0
# Error inserting data for LVA: no such column: 0
# Error inserting data for MAC: no such column: 0
# Error inserting data for MAR: no such column: 0
# Error inserting data for MCO: no such column: 0
# Error inserting data for MDA: no such column: 0
# Error inserting data for MDG: no such column: 0
# Error inserting data for MDV: no such column: 0
# Error inserting data for MEX: no such column: 0
# Error inserting data for MHL: no such column: 0
# Error inserting data for MKD: no such column: 0
# Error inserting data for MLI: no such column: 0
# Error inserting data for MLT: no such column: 0
# Error inserting data for MMR: no such column: 0
# Error inserting data for MNE: no such column: 0
# Error inserting data for MNG: no such column: 0
# Error inserting data for MNP: no such column: 0
# Error inserting data for MOZ: no such column: 0
# Error inserting data for MRT: no such column: 0
# Error inserting data for MSR: no such column: 0
# Error inserting data for MTQ: no such column: 0
# Error inserting data for MUS: no such column: 0
# Error inserting data for MWI: no such column: 0
# Error inserting data for MYS: no such column: 0
# Error inserting data for MYT: no such column: 0
# Error inserting data for NAM: no such column: 0
# Error inserting data for NCL: no such column: 0
# Error inserting data for NER: no such column: 0
# Error inserting data for NFK: no such column: 0
# Error inserting data for NGA: no such column: 0
# Error inserting data for NIC: no such column: 0
# Error inserting data for NIU: no such column: 0
# Error inserting data for NLD: no such column: 0
# Error inserting data for NOR: no such column: 0
# Error inserting data for NPL: no such column: 0
# Error inserting data for NRU: no such column: 0
# Error inserting data for NZL: no such column: 0
# Error inserting data for OMN: no such column: 0
# Error inserting data for PAK: no such column: 0
# Error inserting data for PAN: no such column: 0
# Error inserting data for PCN: no such column: 0
# Error inserting data for PER: no such column: 0
# Error inserting data for PHL: no such column: 0
# Error inserting data for PLW: no such column: 0
# Error inserting data for PNG: no such column: 0
# Error inserting data for POL: no such column: 0
# Error inserting data for PRI: no such column: 0
# Error inserting data for PRT: no such column: 0
# Error inserting data for PRY: no such column: 0
# Error inserting data for PSE: no such column: 0
# Error inserting data for PYF: no such column: 0
# Error inserting data for QAT: no such column: 0
# Error inserting data for REU: no such column: 0
# Error inserting data for ROU: no such column: 0
# Error inserting data for RUS: no such column: 0
# Error inserting data for RWA: no such column: 0
# Error inserting data for SAU: no such column: 0
# Error inserting data for SDN: no such column: 0
# Error inserting data for SEN: no such column: 0
# Error inserting data for SGP: no such column: 0
# Error inserting data for SGS: no such column: 0
# Error inserting data for SHN: no such column: 0
# Error inserting data for SJM: no such column: 0
# Error inserting data for SLB: no such column: 0
# Error inserting data for SLE: no such column: 0
# Error inserting data for SLV: no such column: 0
# Error inserting data for SMR: no such column: 0
# Error inserting data for SOM: no such column: 0
# Error inserting data for SPM: no such column: 0
# Error inserting data for SRB: no such column: 0
# Error inserting data for SSD: no such column: 0
# Error inserting data for STP: no such column: 0
# Error inserting data for SUR: no such column: 0
# Error inserting data for SVK: no such column: 0
# Error inserting data for SVN: no such column: 0
# Error inserting data for SWE: no such column: 0
# Error inserting data for SWZ: no such column: 0
# Error inserting data for SYC: no such column: 0
# Error inserting data for SYR: no such column: 0
# Error inserting data for TCA: no such column: 0
# Error inserting data for TCD: no such column: 0
# Error inserting data for TGO: no such column: 0
# Error inserting data for THA: no such column: 0
# Error inserting data for TJK: no such column: 0
# Error inserting data for TKL: no such column: 0
# Error inserting data for TKM: no such column: 0
# Error inserting data for TLS: no such column: 0
# Error inserting data for TON: no such column: 0
# Error inserting data for TTO: no such column: 0
# Error inserting data for TUN: no such column: 0
# Error inserting data for TUR: no such column: 0
# Error inserting data for TUV: no such column: 0
# Error inserting data for TWN: no such column: 0
# Error inserting data for TZA: no such column: 0
# Error inserting data for UGA: no such column: 0
# Error inserting data for UKR: no such column: 0
# Error inserting data for URY: no such column: 0
# Error inserting data for USA: no such column: 0
# Error inserting data for UZB: no such column: 0
# Error inserting data for VCT: no such column: 0
# Error inserting data for VEN: no such column: 0
# Error inserting data for VNM: no such column: 0
# Error inserting data for VUT: no such column: 0
# Error inserting data for WLF: no such column: 0
# Error inserting data for WSM: no such column: 0
# Error inserting data for YEM: no such column: 0
# Error inserting data for ZAF: no such column: 0
# Error inserting data for ZMB: no such column: 0
# Error inserting data for ZWE: no such column: 0
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[19], line 66
#      63 transform_distance_matrix(db_file)
#      65 # Then get the results
# ---> 66 results = get_trade_emissions_with_distances(db_file)
#
# Cell In[19], line 57, in get_trade_emissions_with_distances(db_file)
#      47 def get_trade_emissions_with_distances(db_file):
#      48     query = """
#      49     SELECT
#      50         t.*,
#    (...)
#      55         AND t.partnerCountryCode = nd.destination_country;
#      56     """
# ---> 57     return execute_query(db_file, query)
#
# Cell In[14], line 37, in execute_query(db_file, query, fetch)
#      35 conn = sqlite3.connect(db_file)
#      36 cursor = conn.cursor()
# ---> 37 cursor.execute(query)
#      38 if fetch:
#      39     results = cursor.fetchall()
#
# OperationalError: no such table: tradeEmissions

# %%
countryDistance = pd.read_csv('country-distances.csv')
tradeEmission = pd.read_csv('TradeData_10_17_2024_13_19_5_cleaned_dropped_zero_cost_countries.csv')

# %%
def merge_trade_and_distances(trade_df, distance_df):
    # Convert distance matrix to long format
    long_distances = pd.melt(
        distance_df, 
        id_vars=distance_df.columns[0],  # First column contains country codes
        var_name='destination_country',
        value_name='distance'
    )
    
    # Rename the first column to 'origin_country'
    long_distances = long_distances.rename(columns={distance_df.columns[0]: 'origin_country'})
    
    # Merge trade data with distances
    result = trade_df.merge(
        long_distances,
        left_on=['countryCode', 'partnerCountryCode'],
        right_on=['origin_country', 'destination_country'],
        how='left'
    )
    
    return result

# Usage
result = merge_trade_and_distances(tradeEmission, countryDistance)

# Now result contains your trade emissions data with the distances added

# %%
country_result = result[~result['partnerCountryCode'].str.contains('\d', na = False)]
reduced_frame = result
# Out:
#        refYear countryCode                        countryISO  \
# 1         2023         ARG                         Argentina
# 3         2023         AUS                         Australia
# 4         2023         AUS                         Australia
# 5         2023         AUS                         Australia
# 7         2023         BOL  Bolivia (Plurinational State of)
# ...        ...         ...                               ...
# 19557     2023         ZMB                            Zambia
# 19558     2023         ZMB                            Zambia
# 19559     2023         ZMB                            Zambia
# 19560     2023         ZMB                            Zambia
# 19561     2023         ZMB                            Zambia
#
#       partnerCountryCode     partnerCountryISO  HSCode  \
# 1                    ARG             Argentina   20130
# 3                    AUS             Australia   20130
# 4                    JPN                 Japan   20130
# 5                    NZL           New Zealand   20130
# 7                    USA                   USA   20130
# ...                  ...                   ...     ...
# 19557                IND                 India  210390
# 19558                ZAF          South Africa  210390
# 19559                ARE  United Arab Emirates  210390
# 19560                GBR        United Kingdom  210390
# 19561                USA                   USA  210390
#
#                                                  cmdCode    motCode Units  \
# 1      Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT    kg
# 3      Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT    kg
# 4      Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT    kg
# 5      Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT    kg
# 7      Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT    kg
# ...                                                  ...        ...   ...
# 19557  Sauces and preparations therefor; mixed condim...      Other    kg
# 19558  Sauces and preparations therefor; mixed condim...      Other    kg
# 19559  Sauces and preparations therefor; mixed condim...      Other    kg
# 19560  Sauces and preparations therefor; mixed condim...      Other    kg
# 19561  Sauces and preparations therefor; mixed condim...      Other    kg
#
#         netWeight  grossWeight     cifvalue  costPerKg            distance
# 1       69700.150   764276.010   708727.510  10.168235                 0.0
# 3       52778.780   832690.546   823195.459  15.597091                 0.0
# 4      111349.300  7954896.306  7044398.315  63.263966         7792.827411
# 5      307969.000  2974549.422  2828523.346   9.184442  2161.0772232784225
# 7         395.851     3922.000     3626.000   9.160012         6572.396345
# ...           ...          ...          ...        ...                 ...
# 19557     470.000      536.326      134.128   0.285379         6197.583155
# 19558    3260.000     4031.164     1007.866   0.309161         2278.299176
# 19559    3610.000     4041.492     1010.389   0.279886         5369.146014
# 19560      10.000      173.815       43.489   4.348900         7908.901488
# 19561      10.000      117.080       29.290   2.929000        12141.233605
#
# [17795 rows x 14 columns]

# %%
country_result.loc[:, 'distance'] = country_result['distance'].astype(float)

# %%
hold = country_result[country_result['motCode']=='TOTAL MOT']
hold[hold['distance']<2000]
# Out:
#        refYear countryCode countryISO partnerCountryCode partnerCountryISO  \
# 1         2023         ARG  Argentina                ARG         Argentina
# 3         2023         AUS  Australia                AUS         Australia
# 9         2023         BRA     Brazil                ARG         Argentina
# 10        2023         BRA     Brazil                PRY          Paraguay
# 11        2023         BRA     Brazil                URY           Uruguay
# ...        ...         ...        ...                ...               ...
# 19333     2023         URY    Uruguay                ARG         Argentina
# 19336     2023         URY    Uruguay                BRA            Brazil
# 19337     2023         URY    Uruguay                CHL             Chile
# 19357     2023         ZMB     Zambia                MWI            Malawi
# 19362     2023         ZMB     Zambia                SWZ          Eswatini
#
#        HSCode                                            cmdCode    motCode  \
# 1       20130  Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT
# 3       20130  Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT
# 9       20130  Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT
# 10      20130  Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT
# 11      20130  Meat; of bovine animals, boneless cuts, fresh ...  TOTAL MOT
# ...       ...                                                ...        ...
# 19333  210390  Sauces and preparations therefor; mixed condim...  TOTAL MOT
# 19336  210390  Sauces and preparations therefor; mixed condim...  TOTAL MOT
# 19337  210390  Sauces and preparations therefor; mixed condim...  TOTAL MOT
# 19357  210390  Sauces and preparations therefor; mixed condim...  TOTAL MOT
# 19362  210390  Sauces and preparations therefor; mixed condim...  TOTAL MOT
#
#       Units    netWeight   grossWeight      cifvalue  costPerKg  \
# 1        kg     69700.15  7.642760e+05  7.087275e+05  10.168235
# 3        kg     52778.78  8.326905e+05  8.231955e+05  15.597091
# 9        kg   1779901.00  1.917127e+07  1.892741e+07  10.633968
# 10       kg  20859060.00  1.214491e+08  1.205179e+08   5.777723
# 11       kg   1165246.00  1.157388e+07  1.149069e+07   9.861174
# ...     ...          ...           ...           ...        ...
# 19333    kg   3806170.00  6.374444e+06  6.165827e+06   1.619956
# 19336    kg    939693.75  1.801113e+06  1.672798e+06   1.780152
# 19337    kg     53793.61  2.231207e+05  2.010499e+05   3.737431
# 19357    kg       930.00  1.831630e+02  4.581400e+01   0.049262
# 19362    kg         3.11  2.048200e+01  5.096000e+00   1.638585
#
#       origin_country destination_country     distance
# 1                ARG                 ARG     0.000000
# 3                AUS                 AUS     0.000000
# 9                BRA                 ARG  1673.973600
# 10               BRA                 PRY  1131.967396
# 11               BRA                 URY  1562.322026
# ...              ...                 ...          ...
# 19333            URY                 ARG   202.985729
# 19336            URY                 BRA  1562.322026
# 19337            URY                 CHL  1341.490584
# 19357            ZMB                 MWI   613.406560
# 19362            ZMB                 SWZ  1269.355560
#
# [2340 rows x 16 columns]

# %% [markdown]
# 8258 for total MOT
# 9537 for NOT total mot

# %%
test=country_result[country_result['countryCode'] != country_result['origin_country']]

# %%
test['partnerCountryCode'].unique()
# Out:
# array(['KOR', 'LAO', '_X ', 'UMI', 'SXM', 'PRK', 'XX '], dtype=object)

# %%
test['countryCode'].unique()
# Out:
# array(['AUS', 'ARG', 'BOL', 'BRA', 'CHL', 'CZE', 'CAN', 'CPV', 'COL',
#        'GUY', 'LUX', 'MUS', 'MDG', 'ISL', 'MEX', 'PHL', 'PRY', 'ROU',
#        'MOZ', 'SVK', 'ZAF', 'SRB', 'USA', 'TUR', 'TZA', 'URY', 'ZMB'],
#       dtype=object)

# %%
sum(country_result['motCode']=='AUS')
# Out:
# 0

# %%
# Get list of unique values
print(country_result['partnerCountryCode'].unique())

# Get count of unique values
print(country_result['partnerCountryCode'].nunique())

# Get value counts (shows how many times each unique value appears)
print(country_result['partnerCountryCode'].value_counts())

# Get value counts as percentages
print(country_result['partnerCountryCode'].value_counts(normalize=True))

# Sort value counts in ascending order (default is descending)
print(country_result['partnerCountryCode'].value_counts().sort_index())

# If you want to see both counts and percentages:
counts = country_result['partnerCountryCode'].value_counts()
percentages = country_result['partnerCountryCode'].value_counts(normalize=True)
summary = pd.DataFrame({
    'count': counts,
    'percentage': percentages
})
print(summary)
# Out:
# ['ARG' 'AUS' 'JPN' 'NZL' 'USA' 'PRY' 'URY' 'BRA' 'CAN' 'ITA' 'ESP' 'DNK'
#  'DEU' 'ISL' 'IRL' 'NLD' 'SWE' 'GBR' 'CHL' 'MEX' 'BEL' 'FRA' 'JOR' 'MYS'
#  'IND' 'VNM' 'GRC' 'AUT' 'BGR' 'CYP' 'HUN' 'IRN' 'LVA' 'NOR' 'POL' 'PRT'
#  'ROU' 'CHE' 'MKD' 'EGY' 'CHN' 'PER' 'MMR' 'BOL' 'COL' 'HKG' 'KEN' 'NPL'
#  'THA' 'PAK' 'KHM' 'LKA' 'BGD' 'IDN' 'IRQ' 'KOR' 'LAO' 'NGA' 'SAU' 'SGP'
#  'ZAF' 'ARE' 'TUR' 'ISR' 'BIH' 'HRV' 'CZE' 'ECU' 'FJI' 'DJI' 'GEO' 'KWT'
#  'LBN' 'LTU' 'LUX' 'MLT' 'MUS' 'MDA' 'OMN' 'NER' 'PHL' 'RUS' 'SRB' 'SYR'
#  'UKR' 'WSM' 'GIB' 'EST' 'GTM' 'ARM' 'COK' 'CRI' 'JAM' 'MLI' 'TLS' 'HND'
#  'BHR' 'BLZ' 'ETH' 'GHA' 'CIV' 'NIC' 'SLE' 'TUN' 'SLV' '_X ' 'FIN' 'MAR'
#  'UMI' 'SVK' 'BWA' 'SVN' 'SEN' 'GIN' 'BTN' 'UGA' 'ALB' 'DOM' 'GAB' 'ASM'
#  'KAZ' 'KGZ' 'UZB' 'DZA' 'AZE' 'BHS' 'CMR' 'COG' 'COD' 'BEN' 'GUY' 'LBR'
#  'LBY' 'MDG' 'TGO' 'TZA' 'BFA' 'VEN' 'PYF' 'DMA' 'HTI' 'LCA' 'TTO' 'MOZ'
#  'ZWE' 'SWZ' 'SUR' 'VCT' 'TKM' 'YEM' 'AFG' 'AND' 'AGO' 'ATG' 'BRB' 'BLR'
#  'GMB' 'MAC' 'NAM' 'NCL' 'AIA' 'ZMB' 'FRO' 'TKL' 'PNG' 'RWA' 'SPM' 'SDN'
#  'GNB' 'MDV' 'TJK' 'ATF' 'SXM' 'NRU' 'CPV' 'PRK' 'SYC' 'COM' 'GRL' 'CUW'
#  'MWI' 'GUM' 'MNE' 'XX ' 'PAN' 'LSO' 'ABW' 'MNG' 'IOT' 'SMR' 'STP' 'MHL'
#  'SOM' 'PSE' 'BDI' 'MRT' 'QAT' 'SLB']
# 198
# partnerCountryCode
# ITA    625
# USA    600
# ESP    596
# FRA    572
# NLD    567
#       ...
# SPM      2
# SLB      2
# GUM      1
# BDI      1
# CUW      1
# Name: count, Length: 198, dtype: int64
# partnerCountryCode
# ITA    0.035122
# USA    0.033717
# ESP    0.033493
# FRA    0.032144
# NLD    0.031863
#          ...
# SPM    0.000112
# SLB    0.000112
# GUM    0.000056
# BDI    0.000056
# CUW    0.000056
# Name: proportion, Length: 198, dtype: float64
# partnerCountryCode
# ABW      2
# AFG     15
# AGO     15
# AIA      2
# ALB     49
#       ...
# YEM      8
# ZAF    269
# ZMB     31
# ZWE     25
# _X      91
# Name: count, Length: 198, dtype: int64
#                     count  percentage
# partnerCountryCode
# ITA                   625    0.035122
# USA                   600    0.033717
# ESP                   596    0.033493
# FRA                   572    0.032144
# NLD                   567    0.031863
# ...                   ...         ...
# SPM                     2    0.000112
# SLB                     2    0.000112
# GUM                     1    0.000056
# BDI                     1    0.000056
# CUW                     1    0.000056
#
# [198 rows x 2 columns]

# %% [markdown]
# ## Tarrif Rates

# %%
csv_file = 'tarrif_rates.csv'
csv_to_sqlite(csv_file, db_file, table_name="tarrif_rates")

# %%
execute_query(db_file, f"""SELECT DISTINCT "Country Name" FROM tarrif_rates""")

# %%
query_filter = f"""

SELECT 
    "Country Name", "Country Code", "Indicator Name", "Indicator Code", "2023"
FROM tarrif_rates
"""

execute_query(db_file, query_filter)

# %% [markdown]
# ### FAO FOOD DATA

# %%
execute_query(db_file, "DROP TABLE IF EXISTS FAOSTAT")

# %%
csv_file = 'FAOSTAT_data.csv'
csv_to_sqlite(csv_file, db_file, table_name="FAOSTAT")

# %%
execute_query(db_file, f"""SELECT * FROM FAOSTAT LIMIT 10""")
